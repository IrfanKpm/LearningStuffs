# %%
# pip install seaborn

# %%
import seaborn as sns

# %%
sns.get_dataset_names()  # dataset ava
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
tips = sns.load_dataset("tips")
titanic = sns.load_dataset('titanic')
iris = sns.load_dataset("iris")

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.scatterplot(x="tip",y="total_bill",data=tips)
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %% [raw]
# 'Hue' parameter is a powerful option that allows you to add an additional categorical variable to your plots.
# When you use hue, Seaborn will use this variable to color or distinguish different elements within the plot, such as data points, bars, or lines.
# This can be especially useful for visualizing the relationships and patterns within your data.

# %%
sns.scatterplot(x="tip",y="total_bill",data=tips,hue="day")
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %%
sns.scatterplot(x="tip",y="total_bill",data=tips,hue="day",size="size")
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %% [raw]
# palette is a color palette or a set of colors that you can use to customize the colors of elements in your plots.
# Seaborn provides a variety of built-in color palettes that you can use to make your visualizations more visually appealing and informative

# %%
sns.scatterplot(x="tip",y="total_bill",data=tips,hue="day",size="size",palette="YlGnBu")
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %%
sns.histplot(tips['tip'])
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
sns.histplot(tips['tip'],kde=True)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
# you can specify the number of bins to control the granularity of your visualization
sns.histplot(tips['tip'],kde=True,bins=30)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
sns.barplot(x="sex",y="tip",data=tips,hue='sex',palette="YlGnBu")
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %%
sns.stripplot(x='day',y='tip',data=tips,hue='sex',palette="YlGnBu")
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.stripplot(x='day',y='tip',data=tips,hue='sex',palette="YlGnBu",dodge=True) # saperate sex
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.jointplot(x='tip',y='total_bill',data=tips,kind='reg')

# %%
sns.jointplot(x='tip',y='total_bill',data=tips,kind='kde')

# %%
sns.jointplot(x='tip',y='total_bill',data=tips,kind='kde',fill=True)

# %%
sns.jointplot(x='tip',y='total_bill',data=tips,kind='kde',fill=True,cmap="YlGnBu")  # cmap :: colormap

# %%
sns.jointplot(x='tip',y='total_bill',data=tips,kind='hex',cmap="YlGnBu")

# %%
titanic.head(10)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         0       3    male  22.0      1      0   7.2500        S   Third
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 2         1       3  female  26.0      0      0   7.9250        S   Third
# 3         1       1  female  35.0      1      0  53.1000        S   First
# 4         0       3    male  35.0      0      0   8.0500        S   Third
# 5         0       3    male   NaN      0      0   8.4583        Q   Third
# 6         0       1    male  54.0      0      0  51.8625        S   First
# 7         0       3    male   2.0      3      1  21.0750        S   Third
# 8         1       3  female  27.0      0      2  11.1333        S   Third
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# ...

# %%
sns.pairplot(titanic.select_dtypes(['number']),hue='pclass')

# %%
new_titanic = titanic[["survived","pclass","age","sibsp","parch","fare"]]

# %%
new_titanic
# Out:
#      survived  pclass   age  sibsp  parch     fare
# 0           0       3  22.0      1      0   7.2500
# 1           1       1  38.0      1      0  71.2833
# 2           1       3  26.0      0      0   7.9250
# 3           1       1  35.0      1      0  53.1000
# 4           0       3  35.0      0      0   8.0500
# ..        ...     ...   ...    ...    ...      ...
# 886         0       2  27.0      0      0  13.0000
# 887         1       1  19.0      0      0  30.0000
# 888         0       3   NaN      1      2  23.4500
# 889         1       1  26.0      0      0  30.0000
# 890         0       3  32.0      0      0   7.7500
#
# [891 rows x 6 columns]

# %%
new_titanic.corr()
# Out:
#           survived    pclass       age     sibsp     parch      fare
# survived  1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# pclass   -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# age      -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# sibsp    -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# parch     0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# fare      0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000

# %%
sns.heatmap(new_titanic.corr(),annot=True,cmap="YlGnBu")
# Out:
# <Axes: >

# %%
sns.heatmap(new_titanic.corr(),annot=True,cmap="coolwarm")
# Out:
# <Axes: >

# %%
sns.heatmap(new_titanic.corr(),annot=True,cmap="icefire")
# Out:
# <Axes: >

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.clustermap(iris.drop("species",axis=1))

# %%
# Source :: https://youtu.be/ooqXQ37XHMM?si=TtWnBYJgFtAh8Fdt
